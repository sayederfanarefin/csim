# %%
# Import pandas library
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.ticker import MaxNLocator

# %%
# initialize list of lists
data1and3 = [[5, 223, 13648, 0.990871], [10, 220, 13647, 0.991178], [15, 227, 13648, 0.990958], [20, 208, 13647, 0.991778], [25, 211, 13648, 0.991559]]
data2 = [[5, 409, 25009, 0.997777], [10, 220, 13647, 0.991178], [15, 141, 9381, 0.989916], [20, 120, 7147, 0.988527], [25, 96, 5761, 0.987989]]
 
# Create the pandas DataFrame
df1and3 = pd.DataFrame(data1and3, columns=['t_update', 'avg cache-hit', 'avg total queries', 'average query delay'])
df2 = pd.DataFrame(data2, columns=['t_query', 'avg cache-hit', 'avg total queries', 'average query delay'])
 

print (df1and3)
print (df2)
# Out:
#    t_update  avg cache-hit  avg total queries  average query delay
# 0         5             22               1365             0.991357
# 1        10             23               1364             0.992967
# 2        15             21               1365             0.991211
# 3        20             21               1365             0.992673
# 4        25             22               1365             0.993553
#    t_query  avg cache-hit  avg total queries  average query delay
# 0        5             42               2501             0.998321
# 1       10             23               1364             0.992967
# 2       15             16                938             0.990201
# 3       20             11                715             0.991329
# 4       25              7                577             0.995156

# %%
df1 = df1and3.drop(["avg total queries", "average query delay"], axis = 1)
df2 = df2.drop(["avg total queries", "avg cache-hit"], axis = 1)
df3 = df1and3.drop(["avg total queries", "avg cache-hit"], axis = 1)


print (df1)
print (df2)
print (df3)
# Out:
#    t_update  avg cache-hit
# 0         5             22
# 1        10             23
# 2        15             21
# 3        20             21
# 4        25             22
#    t_query  average query delay
# 0        5             0.998321
# 1       10             0.992967
# 2       15             0.990201
# 3       20             0.991329
# 4       25             0.995156
#    t_update  average query delay
# 0         5             0.991357
# 1        10             0.992967
# 2        15             0.991211
# 3        20             0.992673
# 4        25             0.993553

# %%
ax = df1.plot(x='t_update', y='avg cache-hit', figsize=(11,4), fontsize=7, linewidth=0.8)
ax.set_title('Scenario 1 [t_query = 10]', fontsize=7)
ax.set_xlabel('T_Update', fontsize=7)
ax.set_ylabel('Cache Hit', fontsize=7)

ax.grid(True)
plt.xticks(rotation = 45) 
plt.show()

# %%
ax = df2.plot(x='t_query', y='average query delay', figsize=(11,4), fontsize=7, linewidth=0.8)
ax.set_title('Scenario 2 [t_update = 10]', fontsize=7)
ax.set_xlabel('T_Query', fontsize=7)
ax.set_ylabel('Avg. Query Delay', fontsize=7)

ax.grid(True)
plt.xticks(rotation = 45) 
plt.show()

# %%
ax = df3.plot(x='t_update', y='average query delay', figsize=(11,4), fontsize=7, linewidth=0.8)
ax.set_title('Scenario 3 [t_query = 10]', fontsize=7)
ax.set_xlabel('T_Update', fontsize=7)
ax.set_ylabel('Avg. Query Delay', fontsize=7)

ax.grid(True)
plt.xticks(rotation = 45) 
plt.show()
